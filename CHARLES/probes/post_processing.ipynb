# %% [markdown]
# ## Importing modules

# %%
# %matplotlib widget

from post import tools
from matplotlib import pyplot as plt
import numpy as np

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

slice_params = {
    'names' : ['x_1over6','x_3over6','x_5over6'], 
    'numbers' : probes.probe_numbers[0:1000],
    'vars' : ['comp(u,0)', 'comp(u,1)', 'comp(u,2)'],
    'parallel' : True
}

LES_params = {
    'uStar': 1,
    'z0': 1
}

plot_params = {
    'levels' : {
        # 'comp(u,0)' : np.linspace(0,.5,200),
        # 'comp(u,1)' : np.linspace(0,4,200)
    }
}

slice = probes.slice_into_df(slice_params)
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=250), Label(value='0 / 250'))), HB…
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_15781/3306443277.py in <module>
#      21 }
#      22
# ---> 23 slice = probes.slice_into_df(slice_params)
#
# ~/Documents/Cascade/city_block/CHARLES/probes/post/tools.py in slice_into_df(self, slice_params)
#     119             mi_series_sliced = mi_series_sliced.apply(parallel_functions)
#     120
# --> 121         mi_df = mi_df.swaplevel(axis = 'columns')
#     122
#     123         et = time.time()
#
# UnboundLocalError: local variable 'mi_df' referenced before assignment
