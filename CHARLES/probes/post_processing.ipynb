# %%
import os
os._exit(00)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
import post.tools as tools
from matplotlib import pyplot as plt
# import pathlib

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
slice_params = {
    'names' : ['x_3over6'], 
    'numbers' : probes.probe_numbers[0:100], 
}

LES_params = {
    'uStar': 1,
    'z0': 1
}

probes.mattia_plot(slice_params, LES_params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_32548/2781844842.py in <module>
#       9 }
#      10
# ---> 11 probes.mattia_plot(slice_params, LES_params)
#
# ~/Documents/Cascade/city_block/CHARLES/probes/post/tools.py in mattia_plot(self, slice_params, LES_params, plot_params)
#     129         data = data_dict_struct.transpose((3,0,2,1))
#     130         data = [0,...] #just looking at u,0 for now
# --> 131         var_cum_avg = np.cumsum(data, axis = -1) / np.arange(0,n_numbers) # cumumlative averge
#     132         plot_data = var_cum_avg.reshape((-1, n_numbers), order = 'C')
#     133
#
# <__array_function__ internals> in cumsum(*args, **kwargs)
#
# ~/codes/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in cumsum(a, axis, dtype, out)
#    2509
#    2510     """
# -> 2511     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#    2512
#    2513
#
# ~/codes/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      53     bound = getattr(obj, method, None)
#      54     if bound is None:
# ---> 55         return _wrapit(obj, method, *args, **kwds)
#      56
#      57     try:
#
# ~/codes/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      42     except AttributeError:
#      43         wrap = None
# ---> 44     result = getattr(asarray(obj), method)(*args, **kwds)
#      45     if wrap:
#      46         if not isinstance(result, mu.ndarray):
#
# TypeError: unsupported operand type(s) for +: 'int' and 'ellipsis'
