# %%
import post.tools as tools
import matplotlib as plt
# import pathlib

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
# probes.data['x_1over6'][79743]['comp(u,0)']

# %%
print(probes.slice_into_np(['x_3over6'],probes.probe_numbers[0:10000]))
# Out:
# [[[[ 9.11589488e-02 -3.62251461e-01  5.86612463e-01]
#    [ 1.61638901e-01 -2.76747316e-01  4.73220199e-01]
#    [ 1.57266319e-01 -3.89457047e-01  4.97008443e-01]
#    ...
#    [ 1.38504648e+00  2.58860819e-04  9.93256271e-03]
#    [ 1.38555467e+00  2.41652204e-04  9.93079692e-03]
#    [ 1.38611162e+00  2.27767203e-04  9.93182138e-03]]
#
#   [[ 1.45704925e-01 -1.92155883e-01  6.03798926e-01]
#    [ 2.51727939e-01 -2.06448048e-01  5.31160772e-01]
#    [ 3.43689144e-01 -2.47711435e-01  4.68214482e-01]
#    ...
#    [ 1.38493395e+00  1.04519620e-03  1.00035407e-02]
#    [ 1.38544726e+00  1.01993035e-03  9.99962538e-03]
#    [ 1.38600755e+00  9.92052606e-04  9.99822654e-03]]
#
#   [[ 4.55335639e-02 -2.94998437e-01  5.51595151e-01]
#    [ 1.73243791e-01 -2.38836050e-01  4.86260623e-01]
#    [ 2.20772773e-01 -4.04051393e-01  4.58564103e-01]
#    ...
#    [ 1.38490641e+00  7.66333775e-04  9.93681978e-03]
#    [ 1.38539636e+00  7.23435427e-04  9.93902609e-03]
#    [ 1.38593781e+00  6.78460812e-04  9.94062796e-03]]
#
#   ...
#
#   [[ 1.60411984e-01 -1.42025813e-01  6.21277392e-01]
#    [ 2.26664335e-01 -2.61565298e-01  4.90725279e-01]
#    [ 2.93305308e-01 -2.56984323e-01  5.04938602e-01]
#    ...
#    [ 1.38500535e+00  2.03383952e-05  9.98269301e-03]
#    [ 1.38551927e+00  5.96842510e-05  9.97787341e-03]
#    [ 1.38607967e+00  1.03228071e-04  9.97578818e-03]]
#
#   [[ 1.49254546e-01 -2.55239308e-01  7.30341673e-01]
#    [ 2.24272311e-01 -3.36927503e-01  5.50353467e-01]
#    [ 2.23955199e-01 -2.50772744e-01  4.73931342e-01]
#    ...
#    [ 1.38499868e+00  1.12523919e-03  9.98619571e-03]
#    [ 1.38551295e+00  1.08566729e-03  9.97996610e-03]
#    [ 1.38607323e+00  1.04325602e-03  9.97683406e-03]]
#
#   [[ 1.25333264e-01 -1.81864902e-01  6.17237389e-01]
#    [ 2.47662932e-01 -2.29941040e-01  5.20583153e-01]
#    [ 3.45642418e-01 -2.53089577e-01  4.49283063e-01]
#    ...
#    [ 1.38494301e+00  1.15690578e-03  1.00071793e-02]
#    [ 1.38545644e+00  1.12558762e-03  1.00031113e-02]
#    [ 1.38601673e+00  1.09099143e-03  1.00014918e-02]]]]

# %%
foo = [1,2,3]
foo[(0,1)]
