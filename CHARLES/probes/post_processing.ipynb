# %%
# %matplotlib widget

import post.tools as tools
from matplotlib import pyplot as plt
import numpy as np
# import pathlib

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
slice_params = {
    'names' : ['x_3over6'], 
    'numbers' : probes.probe_numbers[0:100]
}

LES_params = {
    'uStar': 1,
    'z0': 1
}

plot_params = {
    'levels' : np.linspace(0,.5,200)
}

probes.mattia_plot(slice_params, LES_params, plot_params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32208/1385374677.py in <module>
#      13 }
#      14
# ---> 15 probes.mattia_plot(slice_params, LES_params, plot_params)
#
# ~/Documents/Cascade/city_block/CHARLES/probes/post/tools.py in mattia_plot(self, slice_params, LES_params, plot_params)
#     134
#     135         data = data[0,...] #just looking at u,0 for now
# --> 136         var_cum_avg = np.cumsum(data, axis = -1) / np.arange(1,n_numbers+1) # cumumlative averge
#     137         data_diff = abs((var_cum_avg - var_cum_avg[...,[-1]])/var_cum_avg[...,[-1]])
#     138         plot_data = data_diff.reshape((-1, n_numbers), order = 'C')
#
# ValueError: operands could not be broadcast together with shapes (10000,161,3) (10000,)
