# %%
# %matplotlib widget

import post.tools as tools
from matplotlib import pyplot as plt
import numpy as np
# import pathlib

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
slice_params = {
    'names' : ['x_1over6', 'x_3over6', 'x_5over6'], 
    # 'numbers' : probes.probe_numbers[0:10000],
    'vars' : ['comp(u,0)', 'comp(u,1)', 'comp(u,1)']
}

LES_params = {
    'uStar': 1,
    'z0': 1
}

plot_params = {
    'levels' : {
        'comp(u,0)' : np.linspace(0,.1,200),
        'comp(u,1)' : np.linspace(0,1,200),
        'comp(u,2)' : np.linspace(0,1,200),
    }
}

probes.mattia_plot(slice_params, LES_params, plot_params)
# Out:
#   File "/tmp/ipykernel_8432/595397294.py", line 3
#     'numbers' : probes.probe_numbers[],
#                                      ^
# SyntaxError: invalid syntax

# %%
np.array(4).ndim
# Out:
# 0
