# %%
import post.tools as tools
from matplotlib import pyplot as plt
# import pathlib

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
np_data = probes.slice_into_np()

# %%
slice_params = {
    'get_names' : ['x_3over6'], 
    'get_numbers' : [probes.probe_numbers[0:100]], 
    'get_stack' : [], 
    'get_vars' : []
}

print(probes.slice_into_np(slice_params))
# plt.plot(probes.slice_into_np(['x_3over6'],[])[0,:,9,0])
# Out:
# /home/nbachand/Documents/Cascade/city_block/CHARLES/probes/post/tools.py:89: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   np_array_select_probes = np_array[get_stack]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_26747/1614060423.py in <module>
# ----> 1 print(probes.slice_into_np(['x_3over6'],probes.probe_numbers[0:100], ['comp(u,0)', 'comp(u,1)']))
#       2 # plt.plot(probes.slice_into_np(['x_3over6'],[])[0,:,9,0])
#
# ~/Documents/Cascade/city_block/CHARLES/probes/post/tools.py in slice_into_np(self, get_names, get_numbers, get_stack, get_vars)
#      87                 df = df[get_vars]
#      88                 np_array = df.to_numpy()
# ---> 89                 np_array_select_probes = np_array[get_stack]
#      90                 numbers_list.append(np_array_select_probes) # get df from data dictionary and convert to np array
#      91             names_list.append(numbers_list) # create nested lists of names[numbers]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
