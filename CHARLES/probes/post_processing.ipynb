# %% [markdown]
# ## Importing modules

# %%
# %matplotlib widget

from post import tools
from matplotlib import pyplot as plt
import numpy as np

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
for i in range(1,11):

    probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
    probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

    slice_params = {
        'names' : ['x_1over6','x_3over6','x_5over6'], 
        'numbers' : probes.probe_numbers[0:1000],
        'vars' : ['comp(u,0)', 'comp(u,1)', 'comp(u,2)'],
        'nCpu' : i
    }

    LES_params = {
        'uStar': 1,
        'z0': 1
    }

    plot_params = {
        'levels' : {
            # 'comp(u,0)' : np.linspace(0,.5,200),
            # 'comp(u,1)' : np.linspace(0,4,200)
        }
    }

    slice = probes.slice_into_np(slice_params)
# Out:
# number of jobs: 1
# slice took 90.252845287323 seconds
# number of jobs: 2
# slice took 103.39086103439331 seconds
# number of jobs: 3
# slice took 101.1358232498169 seconds
# number of jobs: 4
# slice took 99.72004675865173 seconds
# number of jobs: 5
# slice took 99.9642493724823 seconds
# number of jobs: 6
# slice took 97.72133588790894 seconds
# number of jobs: 7
# slice took 98.26593351364136 seconds
# number of jobs: 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13254/4196409431.py in <module>
#      23     }
#      24
# ---> 25     slice = probes.slice_into_np(slice_params)
#
# ~/Documents/Cascade/city_block/CHARLES/probes/post/tools.py in slice_into_np(self, slice_params)
#     121             prl_inputs = zip(name_dict_iter, slice_params['numbers'], slice_param_iter)
#     122
# --> 123             numbers_list = list(Parallel(
#     124                 n_jobs=prl_jobs, prefer="threads")(
#     125                     delayed(np_from_dict)(input)
#
# ~/codes/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/codes/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/codes/anaconda3/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/codes/anaconda3/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/codes/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# ~/codes/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
