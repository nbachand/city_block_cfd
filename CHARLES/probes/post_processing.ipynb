# %%
import post.tools as tools
import matplotlib as plt
# import pathlib

# %%
# working_dir = pathlib.Path().absolute()
working_dir = '/home/nbachand/Documents/Cascade/city_block'

probes = tools.Probes(f'{working_dir}/CHARLES/probes/probesOut')
probes.get_locations(f'{working_dir}/CHARLES/probes/locations')

# print(probes.data['x_1over6'][79743]['comp(u,0)'])
# print(probes.data['x_1over6'][79743]['comp(u,0)'])

# print(probes.locations['x_1over6'])
# print(probes.locations['x_1over6'])

# %%
# probes.data['x_1over6'][79743]['comp(u,0)']

# %%
print(probes.slice_into_np([],[79743]))
# Out:
# [[[[-6.57369643e-02  2.39805062e-03  3.23090097e-03]
#    [-5.50100878e-02 -8.44130293e-03 -2.09819246e-02]
#    [-5.54292127e-02 -5.70595674e-02 -1.22633344e-02]
#    ...
#    [ 1.38430297e+00  9.93059948e-05  9.90229845e-03]
#    [ 1.38480961e+00  1.33801615e-04  9.87144187e-03]
#    [ 1.38543797e+00  1.61200864e-04  9.87694971e-03]]]
#
#
#  [[[ 4.50320393e-02 -1.22110598e-01  2.62630910e-01]
#    [ 1.04927421e-01 -1.77145466e-01  1.79091573e-01]
#    [ 9.48999301e-02 -1.62679717e-01  1.25635758e-01]
#    ...
#    [ 1.38402855e+00 -8.21681606e-05  9.21155140e-03]
#    [ 1.38438284e+00 -5.36921470e-05  9.17683076e-03]
#    [ 1.38486707e+00 -2.74938902e-05  9.15602595e-03]]]
#
#
#  [[[-7.99483731e-02  1.26158148e-02 -6.22850545e-02]
#    [-7.51169026e-02  5.33397049e-02 -6.28034249e-02]
#    [-4.99311760e-02  8.44529346e-02 -3.87111008e-02]
#    ...
#    [ 1.38426769e+00  5.60812514e-05  9.97815933e-03]
#    [ 1.38475430e+00  1.03436927e-04  9.99797229e-03]
#    [ 1.29509795e+00 -3.37696023e-04  1.02922628e-02]]]]
