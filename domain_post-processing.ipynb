# %% [markdown]
# ## Setup

# %%
# %matplotlib widget

from pyCascade import probePost, physics
from matplotlib import pyplot as plt
import numpy as np

run = 1
category =  "domain"

# %%
# ############ CLUSTER ################
# scratch_dir = '/scratch/users/nbachand/Cascade/city_block_cfd'
# home_dir = '/home/users/nbachand/Cascade/city_block_cfd'

########### LOCAL ###################
home_dir = '/home/nbachand/Documents/Cascade/city_block'
scratch_dir = home_dir

# %%
rho = 1.225
mu = 1.7894e-5
Re_tau = 43300
Lz =  480
hm = 20
fric_vel = Re_tau*mu/(hm*rho)

z_0 = 0.061*hm #used for convention, but really y_0
disp = 1.11*hm
shear_vel = fric_vel*np.sqrt(1-disp/Lz)
vK_const = 0.4

LES_params = {
    'uStar': shear_vel,
    'z0': z_0,
    'disp': disp,
    'vK_const': vK_const,
    'Dt': .01,
    'z_values' : np.linspace(0,Lz,Lz*10)
}
physics_setup = physics.LES_Physics(LES_params)
physics_setup.plot_log_wind()

# checking against charles code
# approximate log law mean profile
y_scaled = (LES_params['z_values']-disp)/z_0
y_scaled = np.maximum(1.0, y_scaled)
ux = (shear_vel/vK_const)*np.log(y_scaled)

plt.plot(ux, LES_params['z_values'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
physics_setup.calc_flatplate_quantities(
    rho = 1.224,
    mu = 1.7894e-5,
    yPlus = 500
    )
# Out:
# U infinity is 0.45768224669677254 with L = 480.0
# flat plate Reynolds number is 15027242.29234871
# wall spacing is 0.45603115286411516 for y+ of 500

# %%
probes = probePost.Probes(f'{scratch_dir}/CHARLES/{category}/R{run}/probes/probesOut')
probes.get_locations(f'{scratch_dir}/CHARLES/{category}/R{run}/probes/locations')

# %%
plot_params = {
    'plot_levels' : {
        # 'comp(u,0)' : np.linspace(0,.5,256),
        # 'comp(u,2)' : np.linspace(-1,1,256)
    },
    'horizontal spacing' : physics_setup.LES_params['Dt'],
    'stack span' : 'y',
    'xlabel': 'time [s]',
    'ylabel' : 'height [m]',
    'ColorNorm': 'Centered'
}

# slice = probes.slice_into_df(slice_params)
(fig, ax) = probes.contour_plots(
#     names = ['x_1over6','x_3over6'], 
    steps = probes.probe_steps[::],
#     quants = ['comp(u,2)'],
    parrallel = True,
    plot_params = plot_params
    )
# Out:
# sorting took 0 seconds
# slicing took 15 seconds
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=3147), Label(value='0 / 3147'))), …
# Process ForkPoolWorker-12:
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
# Process ForkPoolWorker-15:
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
# Process ForkPoolWorker-11:
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-6:
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 15, in read_probes
#     return df.stack().to_dict()  # save as tuple indexed dictionary
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 1720, in to_dict
#     return into_c((k, maybe_box_native(v)) for k, v in self.items())
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 1720, in <genexpr>
#     return into_c((k, maybe_box_native(v)) for k, v in self.items())
# KeyboardInterrupt
# Traceback (most recent call last):
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-14:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-13:
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 405, in __init__
#     data, index = self._init_dict(data, index, dtype)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 490, in _init_dict
#     s = create_series_with_explicit_dtype(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py", line 834, in create_series_with_explicit_dtype
#     return Series(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 368, in __init__
#     index = ensure_index(index)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 6336, in ensure_index
#     return Index(index_like, copy=copy)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/data_types/series.py", line 26, in work
#     return data.apply(
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 489, in __new__
#     return MultiIndex.from_tuples(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py", line 202, in new_meth
#     return meth(self_or_cls, *args, **kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py", line 560, in from_tuples
#     return cls.from_arrays(arrays, sortorder=sortorder, names=names)
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
# KeyboardInterrupt
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 15, in read_probes
#     return df.stack().to_dict()  # save as tuple indexed dictionary
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 14, in read_probes
#     df = pd.read_csv(filename, delim_whitespace=True)  # read as dataframe
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 405, in __init__
#     data, index = self._init_dict(data, index, dtype)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 490, in _init_dict
#     s = create_series_with_explicit_dtype(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py", line 834, in create_series_with_explicit_dtype
#     return Series(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 439, in __init__
#     data = sanitize_array(data, index, dtype, copy)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 14, in read_probes
#     df = pd.read_csv(filename, delim_whitespace=True)  # read as dataframe
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 488, in _read
#     return parser.read(nrows)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 1720, in to_dict
#     return into_c((k, maybe_box_native(v)) for k, v in self.items())
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py", line 571, in sanitize_array
#     subarr = maybe_convert_platform(data)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1059, in read
#     df = DataFrame(col_dict, columns=columns, index=index)
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 1720, in <genexpr>
#     return into_c((k, maybe_box_native(v)) for k, v in self.items())
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py", line 614, in __init__
#     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 14, in read_probes
#     df = pd.read_csv(filename, delim_whitespace=True)  # read as dataframe
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py", line 118, in maybe_convert_platform
#     arr = construct_1d_object_array_from_listlike(values)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py", line 440, in dict_to_mgr
#     arrays = list(arrays)
# KeyboardInterrupt
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 734, in __len__
#     return len(self._mgr)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py", line 1990, in construct_1d_object_array_from_listlike
#     result[:] = values
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 14, in read_probes
#     df = pd.read_csv(filename, delim_whitespace=True)  # read as dataframe
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 15, in read_probes
#     return df.stack().to_dict()  # save as tuple indexed dictionary
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py", line 35, in __len__
#     return len(self.items)
# KeyboardInterrupt
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py", line 210, in closure
#     return user_defined_function(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 794, in __len__
#     def __len__(self) -> int:
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 27, in parallel_functions
#     return pd.Series(utils.eval_tuple(value))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 1720, in to_dict
#     return into_c((k, maybe_box_native(v)) for k, v in self.items())
#   File "/home/nbachand/codes/pyCascade/pyCascade/utils.py", line 24, in eval_tuple
#     value = function(arg)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 1669, in items
#     return zip(iter(self.index), iter(self))
# KeyboardInterrupt
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/base.py", line 754, in __iter__
#     return map(self._values.item, range(self._values.size))
#   File "/home/nbachand/codes/pyCascade/pyCascade/probePost.py", line 14, in read_probes
#     df = pd.read_csv(filename, delim_whitespace=True)  # read as dataframe
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py", line 51, in __init__
#     self._open_handles(src, kwds)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py", line 222, in _open_handles
#     self.handles = get_handle(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 488, in _read
#     return parser.read(nrows)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1059, in read
#     df = DataFrame(col_dict, columns=columns, index=index)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/common.py", line 609, in get_handle
#     ioargs = _get_filepath_or_buffer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 488, in _read
#     return parser.read(nrows)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 706, in _values
#     return self._mgr.internal_values()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1059, in read
#     df = DataFrame(col_dict, columns=columns, index=index)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 1676, in internal_values
#     return self._block.values
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py", line 614, in __init__
#     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py", line 614, in __init__
#     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py", line 464, in dict_to_mgr
#     return arrays_to_mgr(
# KeyboardInterrupt
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py", line 129, in arrays_to_mgr
#     columns = ensure_index(columns)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py", line 464, in dict_to_mgr
#     return arrays_to_mgr(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py", line 51, in __init__
#     self._open_handles(src, kwds)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 6333, in ensure_index
#     return Index(index_like, copy=copy, tupleize_cols=False)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py", line 222, in _open_handles
#     self.handles = get_handle(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 494, in __new__
#     subarr = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py", line 135, in arrays_to_mgr
#     return create_block_manager_from_arrays(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/common.py", line 609, in get_handle
#     ioargs = _get_filepath_or_buffer(
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 1774, in create_block_manager_from_arrays
#     mgr = BlockManager(blocks, axes)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/common.py", line 300, in _get_filepath_or_buffer
#     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/common.py", line 300, in _get_filepath_or_buffer
#     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 914, in __init__
#     self._verify_integrity()
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/common.py", line 239, in asarray_tuplesafe
#     return construct_1d_object_array_from_listlike(values)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/common.py", line 140, in is_url
#     return parse_url(url).scheme in _VALID_URLS
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/io/common.py", line 140, in is_url
#     return parse_url(url).scheme in _VALID_URLS
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 917, in _verify_integrity
#     mgr_shape = self.shape
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/urllib/parse.py", line 393, in urlparse
#     splitresult = urlsplit(url, scheme, allow_fragments)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py", line 1990, in construct_1d_object_array_from_listlike
#     result[:] = values
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/urllib/parse.py", line 461, in urlsplit
#     url = url.replace(b, "")
# KeyboardInterrupt
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py", line 43, in shape
#     return tuple(len(ax) for ax in self.axes)
# KeyboardInterrupt
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py", line 43, in <genexpr>
#     return tuple(len(ax) for ax in self.axes)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/urllib/parse.py", line 393, in urlparse
#     splitresult = urlsplit(url, scheme, allow_fragments)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/urllib/parse.py", line 489, in urlsplit
#     _checknetloc(netloc)
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py", line 806, in __len__
#     def __len__(self) -> int:
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32203/2766489314.py in <module>
#      12
#      13 # slice = probes.slice_into_df(slice_params)
# ---> 14 (fig, ax) = probes.contour_plots(
#      15 #     names = ['x_1over6','x_3over6'],
#      16     steps = probes.probe_steps[::],
#
# ~/codes/pyCascade/pyCascade/probePost.py in contour_plots(self, names, steps, quants, stack, parrallel, processing, plot_params)
#     166         quants, stack, names, steps = [self.get_input(input) for input in [quants, stack, names, steps]]
#     167
# --> 168         data = self.slice_into_df(names, steps, parrallel)
#     169         data = data.loc[(stack,quants),:]
#     170         n_names = len(names)
#
# ~/codes/pyCascade/pyCascade/probePost.py in slice_into_df(self, names, steps, parallel)
#     132             pandarallel.initialize(progress_bar=True)
#     133             # read in data directly (not indecing self.data)
# --> 134             mi_df = mi_series_sliced.parallel_apply(parallel_functions)
#     135         else:
#     136             mi_df = mi_series_sliced.apply(parallel_functions)
#
# ~/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py in closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     305                 )
#     306             ):
# --> 307                 message: Tuple[int, WorkerStatus, Any] = master_workers_queue.get()
#     308                 worker_index, worker_status, payload = message
#     309                 workers_status[worker_index] = worker_status
#
# <string> in get(self, *args, **kwds)
#
# ~/codes/anaconda3/lib/python3.9/multiprocessing/managers.py in _callmethod(self, methodname, args, kwds)
#     808
#     809         conn.send((self._id, methodname, args, kwds))
# --> 810         kind, result = conn.recv()
#     811
#     812         if kind == '#RETURN':
#
# ~/codes/anaconda3/lib/python3.9/multiprocessing/connection.py in recv(self)
#     253         self._check_closed()
#     254         self._check_readable()
# --> 255         buf = self._recv_bytes()
#     256         return _ForkingPickler.loads(buf.getbuffer())
#     257
#
# ~/codes/anaconda3/lib/python3.9/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     417
#     418     def _recv_bytes(self, maxsize=None):
# --> 419         buf = self._recv(4)
#     420         size, = struct.unpack("!i", buf.getvalue())
#     421         if size == -1:
#
# ~/codes/anaconda3/lib/python3.9/multiprocessing/connection.py in _recv(self, size, read)
#     382         remaining = size
#     383         while remaining > 0:
# --> 384             chunk = read(handle, remaining)
#     385             n = len(chunk)
#     386             if n == 0:
#
# KeyboardInterrupt:

# %%
# plt.savefig(f'{home_dir}/CHARLES/R{run}/plots/velocity_contour')

# %%
plot_params = {
    'plot_levels' : {
        'comp(u,0)' : np.linspace(0,.1,200),
        'comp(u,1)' : np.linspace(0,.1,200),
        'comp(u,2)' : np.linspace(0,.1,200)
    },
    'horizontal spacing' : physics_setup.LES_params['Dt'],
    'stack span' : 'y',
    'xlabel': 'time [s]',
    'ylabel' : 'height',
    'plot_every': 1000
}

# slice = probes.slice_into_df(slice_params)
(fig, ax) = probes.contour_plots(
    # names = ['x_1over6','x_3over6'], 
    steps = probes.probe_steps[:-4],
#     quants = ['comp(u,0)', 'comp(u,1)'],
    parrallel = True,
    processing = [probePost.mean_convergence],
    plot_params = plot_params
    )

# %%
probes.profile_plots(
    # names = ['x_3over6'],
    steps = probes.probe_steps[-10],
    quants = ['comp(u,0)'],
    plot_params = {
        'stack span' : 'y',
        'xlabel': 'velocity [1/s]',
        'ylabel' : 'height'
        },
    parrallel=True
    )

physics_setup.plot_log_wind()
# Out:
# sorting took 0 seconds
# slicing took 0 seconds
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1), Label(value='0 / 1'))), HBox(c…
# reading data took 0 seconds
# memorizing data took 0 seconds
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
