# %% [markdown]
# ## Setup

# %%
# %matplotlib widget

from pyCascade import probePost, physics
from matplotlib import pyplot as plt
import numpy as np

run = 3
category =  "domain"

# %%
# ############ CLUSTER ################
# scratch_dir = '/scratch/users/nbachand/Cascade/city_block_cfd'
# home_dir = '/home/users/nbachand/Cascade/city_block_cfd'

########### LOCAL ###################
home_dir = '/home/nbachand/Documents/Cascade/city_block'
scratch_dir = home_dir

# %%
rho = 1.225
mu = 1.7894e-5
Re_tau = 43300
Lz =  480
hm = 20
fric_vel = Re_tau*mu/(hm*rho)

z_0 = 0.061*hm #used for convention, but really y_0
disp = 1.11*hm
shear_vel = fric_vel*np.sqrt(1-disp/Lz)
vK_const = 0.4

LES_params = {
    'uStar': shear_vel,
    'z0': z_0,
    'disp': disp,
    'vK_const': vK_const,
    'Dt': 10,
    'z_values' : np.linspace(0,Lz,Lz*10)
}
physics_setup = physics.LES_Physics(LES_params)
physics_setup.plot_log_wind()

# checking against charles code
# approximate log law mean profile
y_scaled = (LES_params['z_values']-disp)/z_0
y_scaled = np.maximum(1.0, y_scaled)
ux = (shear_vel/vK_const)*np.log(y_scaled)

plt.plot(ux, LES_params['z_values'])

# %%
physics_setup.calc_flatplate_quantities(
    rho = 1.224,
    mu = 1.7894e-5,
    yPlus = 500
    )
# Out:
# U infinity is 0.45768224669677254 with L = 480.0
# flat plate Reynolds number is 15027242.29234871
# wall spacing is 0.45603115286411516 for y+ of 500

# %%
physics_setup.LES_params['uStar']
# Out:
# 0.03088492282600406

# %%
probes = probePost.Probes(f'{scratch_dir}/CHARLES/{category}/R{run}/probes/probesOut')
probes.get_locations(f'{scratch_dir}/CHARLES/{category}/R{run}/probes/locations')

# %%
plot_params = {
    'plot_levels' : {
        # 'comp(u,0)' : np.linspace(0,.5,256),
        # 'comp(u,2)' : np.linspace(-1,1,256)
    },
    'horizontal spacing' : physics_setup.LES_params['Dt'],
    'stack span' : 'y',
    'xlabel': 'time [s]',
    'ylabel' : 'height [m]',
    'ColorNorm': 'Centered'
}

# slice = probes.slice_into_df(slice_params)
(fig, ax) = probes.contour_plots(
    names = ['x_3over6'], 
    steps = probes.probe_steps[0::100],
    quants = ['comp(u,0)'],
    parrallel = True,
    plot_params = plot_params
    )
# Out:
# slicing took 11 seconds
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=240), Label(value='0 / 240'))), HB…
# reading data took 8 seconds
# memorizing data took 1 seconds
# plotting took 9 seconds

# %%
# plt.savefig(f'{home_dir}/CHARLES/R{run}/plots/velocity_contour')

# %%
plot_params = {
    'plot_levels' : {
        'comp(u,0)' : np.linspace(0,.1,200),
        'comp(u,1)' : np.linspace(0,.1,200),
        'comp(u,2)' : np.linspace(0,.1,200)
    },
    'horizontal spacing' : physics_setup.LES_params['Dt'],
    'stack span' : 'y',
    'xlabel': 'time [s]',
    'ylabel' : 'height',
    'plot_every': 100
}

# slice = probes.slice_into_df(slice_params)
(fig, ax) = probes.contour_plots(
    # names = ['x_1over6','x_3over6'], 
    steps = probes.probe_steps[:-4],
#     quants = ['comp(u,0)', 'comp(u,1)'],
    parrallel = True,
    processing = [probePost.mean_convergence],
    plot_params = plot_params
    )
# Out:
# slicing took 12 seconds
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=23913), Label(value='0 / 23913')))…
# Process ForkPoolWorker-45:
# Traceback (most recent call last):
#   File "/home/nbachand/codes/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11992/4190663005.py in <module>
#      13
#      14 # slice = probes.slice_into_df(slice_params)
# ---> 15 (fig, ax) = probes.contour_plots(
#      16     # names = ['x_1over6','x_3over6'],
#      17     steps = probes.probe_steps[:-4],
#
# ~/codes/pyCascade/pyCascade/probePost.py in contour_plots(self, names, steps, quants, stack, parrallel, processing, plot_params)
#     167         quants, stack, names, steps = [self.get_input(input) for input in [quants, stack, names, steps]]
#     168
# --> 169         data = self.slice_into_df(names, steps, parrallel)
#     170         data = data.loc[(stack,quants),:]
#     171         n_names = len(names)
#
# ~/codes/pyCascade/pyCascade/probePost.py in slice_into_df(self, names, steps, parallel)
#     133             pandarallel.initialize(progress_bar=True)
#     134             # read in data directly (not indecing self.data)
# --> 135             mi_df = mi_series_sliced.parallel_apply(parallel_functions)
#     136         else:
#     137             mi_df = mi_series_sliced.apply(parallel_functions)
#
# ~/codes/anaconda3/lib/python3.9/site-packages/pandarallel/core.py in closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     317
#     318                     if next(generation) % nb_workers == 0:
# --> 319                         progress_bars.update(progresses)
#     320                 elif worker_status == WorkerStatus.Error:
#     321                     progress_bars.set_error(worker_index)
#
# ~/codes/anaconda3/lib/python3.9/site-packages/pandarallel/progress_bars.py in update(self, values)
#     156
#     157             bar.value = value
# --> 158             bar.description = "{:.2f}%".format(value / bar.max * 100)
#     159
#     160             if value >= bar.max:
#
# ~/codes/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     604             raise TraitError('The "%s" trait is read-only.' % self.name)
#     605         else:
# --> 606             self.set(obj, value)
#     607
#     608     def _validate(self, obj, value):
#
# ~/codes/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     593             # we explicitly compare silent to True just in case the equality
#     594             # comparison above returns something other than True/False
# --> 595             obj._notify_trait(self.name, old_value, new_value)
#     596
#     597     def __set__(self, obj, value):
#
# ~/codes/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1217
#    1218     def _notify_trait(self, name, old_value, new_value):
# -> 1219         self.notify_change(Bunch(
#    1220             name=name,
#    1221             old=old_value,
#
# ~/codes/anaconda3/lib/python3.9/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     603             if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     604                 # Send new state to front-end
# --> 605                 self.send_state(key=name)
#     606         super(Widget, self).notify_change(change)
#     607
#
# ~/codes/anaconda3/lib/python3.9/site-packages/ipywidgets/widgets/widget.py in send_state(self, key)
#     487             state, buffer_paths, buffers = _remove_buffers(state)
#     488             msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 489             self._send(msg, buffers=buffers)
#     490
#     491
#
# ~/codes/anaconda3/lib/python3.9/site-packages/ipywidgets/widgets/widget.py in _send(self, msg, buffers)
#     735         """Sends a message to the model in the front-end."""
#     736         if self.comm is not None and self.comm.kernel is not None:
# --> 737             self.comm.send(data=msg, buffers=buffers)
#     738
#     739     def _repr_keys(self):
#
# ~/codes/anaconda3/lib/python3.9/site-packages/ipykernel/comm/comm.py in send(self, data, metadata, buffers)
#     120     def send(self, data=None, metadata=None, buffers=None):
#     121         """Send a message to the frontend-side version of this comm"""
# --> 122         self._publish_msg('comm_msg',
#     123             data=data, metadata=metadata, buffers=buffers,
#     124         )
#
# ~/codes/anaconda3/lib/python3.9/site-packages/ipykernel/comm/comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      64         metadata = {} if metadata is None else metadata
#      65         content = json_clean(dict(data=data, comm_id=self.comm_id, **keys))
# ---> 66         self.kernel.session.send(self.kernel.iopub_socket, msg_type,
#      67             content,
#      68             metadata=json_clean(metadata),
#
# ~/codes/anaconda3/lib/python3.9/site-packages/jupyter_client/session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     715             buffers = buffers or msg.get('buffers', [])
#     716         else:
# --> 717             msg = self.msg(msg_or_type, content=content, parent=parent,
#     718                            header=header, metadata=metadata)
#     719         if self.check_pid and not os.getpid() == self.pid:
#
# ~/codes/anaconda3/lib/python3.9/site-packages/jupyter_client/session.py in msg(self, msg_type, content, parent, header, metadata)
#     575         """
#     576         msg = {}
# --> 577         header = self.msg_header(msg_type) if header is None else header
#     578         msg['header'] = header
#     579         msg['msg_id'] = header['msg_id']
#
# ~/codes/anaconda3/lib/python3.9/site-packages/jupyter_client/session.py in msg_header(self, msg_type)
#     565
#     566     def msg_header(self, msg_type):
# --> 567         return msg_header(self.msg_id, msg_type, self.username, self.session)
#     568
#     569     def msg(self, msg_type, content=None, parent=None, header=None, metadata=None):
#
# ~/codes/anaconda3/lib/python3.9/site-packages/jupyter_client/session.py in msg_id(self)
#     515         message_number = self.message_count
#     516         self.message_count += 1
# --> 517         return '{}_{}'.format(self.session, message_number)
#     518
#     519     def _check_packers(self):
#
# KeyboardInterrupt:

# %%
probes.profile_plots(
    # names = ['x_3over6'],
    steps = probes.probe_steps[-100:],
    quants = ['comp(u,0)'],
    plot_params = {
        'stack span' : 'y',
        'xlabel': 'velocity [1/s]',
        'ylabel' : 'height'
        },
    parrallel=True
    )

physics_setup.plot_log_wind()
# Out:
# slicing took 12 seconds
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=9), Label(value='0 / 9'))), HBox(c…
# reading data took 2 seconds
# memorizing data took 0 seconds
